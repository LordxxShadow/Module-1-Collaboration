# %% [markdown]
# ### 11.1
#
# Create a file called `zoo.py` with a function called `hours()` that prints `Open 9-5 daily`. Then import the `zoo` module and call the `hours()` function.

# %%
# %%writefile zoo.py

def hours():
    print("Open 9-5 daily")
# Out:
# Overwriting zoo.py

# %%
import zoo

zoo.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ### 11.2
#
# Import the `zoo` module as `menagerie` and call its `hours()` function.

# %%
import zoo as menagerie

menagerie.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ### 16.4
#
# Use the `sqlite3` module to create a SQLite database called `books.db` and a table called `books` with the fields `title` (text), `author` (text), and `year` (integer).

# %%
import sqlite3

conn = sqlite3.connect("books.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS books (
    title TEXT,
    author TEXT,
    year INTEGER
)
""")

conn.commit()

# %% [markdown]
# ### 16.5
#
# Read `books2.csv` and insert its data into the `books` table.

# %%
# %%writefile books2.csv
# title,author,year
# The Weirdstone of Brisingamen,Alan Garner,1960
# Perdido Street Station,China Miéville,2000
# Thud!,Terry Pratchett,2005
# The Spellman Files,Lisa Lutz,2007
# Small Gods,Terry Pratchett,1992
# import csv
#
# with open("books2.csv", "r", encoding="utf-8") as file:
#     books = csv.DictReader(file)
#
#     for book in books:
#         cursor.execute(
#             "INSERT INTO books (title, author, year) VALUES (?, ?, ?)",
#             (book["title"], book["author"], int(book["year"]))
#         )
#
# conn.commit()
# Out:
# Writing books2.csv

# %% [markdown]
# ### 16.8
#
# Use the `sqlalchemy` module to connect to the SQLite database `books.db`. Select and print the `title` column from the `books` table in alphabetical order.

# %%
# !pip install sqlalchemy
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///books.db")

with engine.connect() as connection:
    result = connection.execute(
        text("SELECT title FROM books ORDER BY title")
    )

    for row in result:
        print(row[0])
